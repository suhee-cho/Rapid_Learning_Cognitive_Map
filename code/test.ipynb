# %%
import run_offline
run_offline.simulate_potentiated_replay(10)
# Out:
# Trial 1/10 — /home/suheecho/BTSP/Rapid_Learning_Cognitive_Map/results/Tmaze/trial0
#   Potentiated synapses: 759478 / 1601485 (47.4%)
#   CA3 PC spikes: 118079
# Now training network with generated spike train...
#   [control] CA3 PC spikes: 69877
# Trial 2/10 — /home/suheecho/BTSP/Rapid_Learning_Cognitive_Map/results/Tmaze/trial1
#   Potentiated synapses: 759741 / 1600331 (47.5%)
#   CA3 PC spikes: 110269
# Now training network with generated spike train...
#   [control] CA3 PC spikes: 73729
# Trial 3/10 — /home/suheecho/BTSP/Rapid_Learning_Cognitive_Map/results/Tmaze/trial2
#   Potentiated synapses: 760186 / 1599562 (47.5%)
#   CA3 PC spikes: 120125
# Now training network with generated spike train...
#   [control] CA3 PC spikes: 72743
# Trial 4/10 — /home/suheecho/BTSP/Rapid_Learning_Cognitive_Map/results/Tmaze/trial3
#   Potentiated synapses: 758728 / 1600128 (47.4%)
#   CA3 PC spikes: 130243
# Now training network with generated spike train...
#   [control] CA3 PC spikes: 80308
# ...
